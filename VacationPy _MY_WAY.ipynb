# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df
# Out:
#      City_ID              City Country                 Date      Lat  \
# 0          0            Hobart      AU  2022-11-10 02:04:58 -42.8794
# 1          1         Busselton      AU  2022-11-10 02:06:56 -33.6500
# 2          2    Saint-Philippe      RE  2022-11-10 02:06:56 -21.3585
# 3          3             Tiksi      RU  2022-11-10 02:06:57  71.6872
# 4          4          Balykshi      KZ  2022-11-10 02:06:57  47.0667
# ..       ...               ...     ...                  ...      ...
# 536      536        Porto Novo      BJ  2022-11-10 02:21:06   6.4965
# 537      537       Brunsbuttel      DE  2022-11-10 02:21:06  53.9000
# 538      538             Lagoa      PT  2022-11-10 02:21:07  39.0500
# 539      539  Puerto Leguizamo      CO  2022-11-10 02:21:08  -0.1934
# 540      540         Fairbanks      US  2022-11-10 02:19:02  64.8378
#
#           Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    147.3294     81.05        46           0       14.97
# ...

# %%
negative_max_df = city_data_df.loc[((city_data_df['Max Temp'] <= 1))]
negative_max_df
# Out:
#      City_ID           City Country                 Date      Lat       Lng  \
# 3          3          Tiksi      RU  2022-11-10 02:06:57  71.6872  128.8694
# 5          5  Leningradskiy      RU  2022-11-10 02:06:57  69.3833  178.4167
# 7          7         Dikson      RU  2022-11-10 02:06:58  73.5069   80.5464
# 37        37      Saskylakh      RU  2022-11-10 02:07:11  71.9167  114.0833
# 64        64       Khatanga      RU  2022-11-10 02:08:22  71.9667  102.5000
# 117      117     Chokurdakh      RU  2022-11-10 02:09:40  70.6333  147.9167
# 133      133        Qaanaaq      GL  2022-11-10 02:09:46  77.4840  -69.3632
# 208      208      Omsukchan      RU  2022-11-10 02:12:14  62.5333  155.8000
# 230      230       Yar-Sale      RU  2022-11-10 02:13:22  66.8333   70.8333
# 231      231     Turukhansk      RU  2022-11-10 02:13:23  65.8167   87.9833
# 240      240  Batagay-Alyta      RU  2022-11-10 02:12:19  67.8006  130.4114
# ...

# %%
negative_max_df[["City_ID"]]
# Out:
#      City_ID
# 3          3
# 5          5
# 7          7
# 37        37
# 64        64
# 117      117
# 133      133
# 208      208
# 230      230
# 231      231
# 240      240
# 354      354
# 356      356
# 369      369
# 371      371
# 374      374
# 378      378
# 394      394
# 420      420
# 446      446
# 486      486
# 497      497

# %%
negative_max = negative_max_df['City_ID'].tolist()
  
# show the list
print(negative_max)
# Out:
# [3, 5, 7, 37, 64, 117, 133, 208, 230, 231, 240, 354, 356, 369, 371, 374, 378, 394, 420, 446, 486, 497]

# %%
city_data_df.drop([3, 5, 7, 37, 64, 117, 133, 208, 230, 231, 240, 354, 356, 369, 371, 374, 378, 394, 420, 446, 486, 497], inplace = True)
city_data_df
# Out:
#      City_ID              City Country                 Date      Lat  \
# 0          0            Hobart      AU  2022-11-10 02:04:58 -42.8794
# 1          1         Busselton      AU  2022-11-10 02:06:56 -33.6500
# 2          2    Saint-Philippe      RE  2022-11-10 02:06:56 -21.3585
# 4          4          Balykshi      KZ  2022-11-10 02:06:57  47.0667
# 6          6       Tuktoyaktuk      CA  2022-11-10 02:06:58  69.4541
# ..       ...               ...     ...                  ...      ...
# 536      536        Porto Novo      BJ  2022-11-10 02:21:06   6.4965
# 537      537       Brunsbuttel      DE  2022-11-10 02:21:06  53.9000
# 538      538             Lagoa      PT  2022-11-10 02:21:07  39.0500
# 539      539  Puerto Leguizamo      CO  2022-11-10 02:21:08  -0.1934
# 540      540         Fairbanks      US  2022-11-10 02:19:02  64.8378
#
#           Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0    147.3294     81.05        46           0       14.97
# ...

# %%
city_data_df = city_data_df.reset_index()
city_data_df
# Out:
#      index  City_ID              City Country                 Date      Lat  \
# 0        0        0            Hobart      AU  2022-11-10 02:04:58 -42.8794
# 1        1        1         Busselton      AU  2022-11-10 02:06:56 -33.6500
# 2        2        2    Saint-Philippe      RE  2022-11-10 02:06:56 -21.3585
# 3        4        4          Balykshi      KZ  2022-11-10 02:06:57  47.0667
# 4        6        6       Tuktoyaktuk      CA  2022-11-10 02:06:58  69.4541
# ..     ...      ...               ...     ...                  ...      ...
# 514    536      536        Porto Novo      BJ  2022-11-10 02:21:06   6.4965
# 515    537      537       Brunsbuttel      DE  2022-11-10 02:21:06  53.9000
# 516    538      538             Lagoa      PT  2022-11-10 02:21:07  39.0500
# 517    539      539  Puerto Leguizamo      CO  2022-11-10 02:21:08  -0.1934
# 518    540      540         Fairbanks      US  2022-11-10 02:19:02  64.8378
#
# ...

# %%
city_data_df.dtypes
# Out:
# index           int64
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# 1. Assign the locations to an array of latitude and longitude pairs.
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# 2. Assign the weights variable to some values.
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# 3. Assign the figure variable to the gmaps.figure() attribute.
fig = gmaps.figure()
# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
# EXAMPLE: heatmap_layer = gmaps.heatmap_layer(locations, weights=temperatures)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# 5. Add the heatmap layer.
# EXAMPLE: fig.add_layer(heatmap_layer)
fig.add_layer(heat_layer)
# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
